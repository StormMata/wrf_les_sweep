# %% [markdown]
# ## Configure sweep on 15 MW turbine with specified shear/veer rates

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from wrf_io import *
from itertools import product
import pickle

# %%
opt_params={}

opt_params['allocation']     = 'ATM170028' 
opt_params['partition']      = 'spr' 
opt_params['runtime']        = '48:00:00'
opt_params['system']         = 'stampede'
opt_params['num_nodes']      = 2

opt_params['exclude_time']   = 10
opt_params['save_interval']  = 10

opt_params['base_dir']       = '/scratch/09909/smata/wrf_les_sweep/runs/15MW/rate/OOS_SV'
opt_params['wrf_path']       = '/work2/09909/smata/stampede3/WRF_LES'
opt_params['template_path']  = '/scratch/09909/smata/wrf_les_sweep/templates'
opt_params['turb_model']     = 'iea15MW'
opt_params['rotor_model']    = 'GAD'
opt_params['slice_loc']      = 1
   
opt_params['print_table']    = True
   
opt_params['plot_outer']     = True
opt_params['save_outer']     = False
opt_params['outer_align']    = False
   
opt_params['plot_inner']     = True
opt_params['save_inner']     = False
   
opt_params['save_both']      = False
opt_params['outer_pad']      = 75

opt_params['plot_profiles']  = True
opt_params['save_profiles']  = True

opt_params['batch_submit']   = True

opt_params['prof_type']      = 'Idealized'
opt_params['shear_type']     = 'Rate'
# opt_params['shear']          = [-0.03,-0.02,-0.01,0,0.01,0.02,0.03]
# opt_params['veer']           = [-0.2,-0.1,-0.05,-0.025,0,0.025,0.05,0.1,0.2]

opt_params['shear']          = [-0.035,-0.025,-0.015,-0.005,0,0.005,0.015,0.025,0.035]
opt_params['veer']           = [-0.25,-0.15,-0.075,-0.035,-0.01,0.01,0.035,0.075,0.15,0.25]

opt_params['excluded_pairs'] = []
# opt_params['excluded_pairs'] = [pair for pair in product([-6,-4,-2,0,2,4,6], [-80,-70,-60,-50,-40,-30,-20,-10,0,10,20,30,40,50,60,70,80])]

opt_params['Ufst']           = 7

# with open('/scratch/09909/smata/wrf_les_sweep/runs/15MW/rate/gad_sweep/parameters.pkl', 'wb') as f:
#     pickle.dump(opt_params, f)

# %%
flag = sweep.setup(opt_params, 'GAD')
# Out:
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━┓
# ┃ Parameter                                 ┃                  Value ┃ Issue ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━┩
# │ TIME CONTROL AND SETUP                    │                        │       │
# │                                           │                        │       │
# │ Run time                                  │            00:00:15:00 │       │
# │                                           │                        │       │
# │ Outer dt                                  │               0.40 sec │       │
# │ Inner dt                                  │               0.04 sec │       │
# │                                           │                        │       │
# │ Processes                                 │                    104 │       │
# ├───────────────────────────────────────────┼────────────────────────┼───────┤
# │ TURBINE                                   │                        │       │
# │                                           │                        │       │
# │ Model                                     │                iea15MW │       │
# │ Diameter                                  │               242.00 m │       │
# │ Hub diameter                              │                 7.90 m │       │
# │ Inner domain x location                   │               1.65 x D │       │
# │ Turbine x location                        │               4.63 x D │       │
# │ z location                                │                378.0 m │       │
# ├───────────────────────────────────────────┼────────────────────────┼───────┤
# │ ROTOR                                     │                        │       │
# │                                           │                        │       │
# │ Model                                     │                    GAD │       │
# │ Rotation                                  │              clockwise │       │
# │ Sections                                  │                    191 │       │
# │ Elements                                  │                     32 │       │
# │                                           │                        │       │
# │ nSeries                                   │                   6112 │       │
# │                                           │                        │       │
# │ V0 location                               │                0.6 x D │   >3D │
# │                                           │                        │       │
# │ Shapiro                                   │                     ON │       │
# ├───────────────────────────────────────────┼────────────────────────┼───────┤
# │ DOMAIN                                    │                        │       │
# │                                           │                        │       │
# │ Outer mesh size                           │              7,087,487 │       │
# │ Inner mesh Size                           │             20,319,607 │       │
# │ Mesh ratio                                │                   2.87 │       │
# │                                           │                        │       │
# │ Outer dx, dy                              │         [40.0, 40.0] m │       │
# │ Inner dx, dy                              │         [ 4.0,  4.0] m │       │
# │ dz                                        │                 4.04 m │       │
# │                                           │                        │       │
# │ Outer [Lx, Ly, Lz]                        │ [41.5, 25.0,  3.1] x D │       │
# │ Inner [Lx, Ly, Lz]                        │ [ 5.0,  6.0,  3.1] x D │       │
# │                                           │                        │       │
# │ Outer [Nx, Ny, Nz]                        │     [ 251,  151,  187] │       │
# │ Inner [Nx, Ny, Nz]                        │     [ 301,  361,  187] │       │
# │                                           │                        │       │
# │ Lateral blockage                          │                  4.01% │       │
# ├───────────────────────────────────────────┼────────────────────────┼───────┤
# │ DECOMPOSITION                             │                        │       │
# │                                           │                        │       │
# │ Outer cell width in x                     │                     31 │       │
# │ Outer cell width in y                     │                     11 │       │
# │                                           │                        │       │
# │ Inner cell width in x                     │                     37 │       │
# │ Inner cell width in y                     │                     27 │       │
# │                                           │                        │       │
# │ MOD(301 - 1, 10)                          │                      0 │       │
# │ MOD(361 - 1, 10)                          │                      0 │       │
# │                                           │                        │       │
# │ Rotor contained in pool?                  │                    Yes │       │
# ├───────────────────────────────────────────┼────────────────────────┼───────┤
# │ INFLOW                                    │                        │       │
# │                                           │                        │       │
# │ Profile type                              │       Linear Idealized │       │
# │                                           │                        │       │
# │ Total cases                               │                     90 │       │
# │                                           │                        │       │
# │ [shear, veer]                             │        Rate [(unit)/m] │       │
# │                                           │                        │       │
# │                                           │        [-0.035,-0.250] │       │
# │                                           │        [-0.035,-0.150] │       │
# │                                           │        [-0.035,-0.075] │       │
# │                                           │        [-0.035,-0.035] │       │
# │                                           │        [-0.035,-0.010] │       │
# │                                           │        [-0.035, 0.010] │       │
# │                                           │        [-0.035, 0.035] │       │
# │                                           │        [-0.035, 0.075] │       │
# │                                           │        [-0.035, 0.150] │       │
# │                                           │        [-0.035, 0.250] │       │
# │                                           │        [-0.025,-0.250] │       │
# │                                           │        [-0.025,-0.150] │       │
# │                                           │        [-0.025,-0.075] │       │
# │                                           │        [-0.025,-0.035] │       │
# │                                           │        [-0.025,-0.010] │       │
# │                                           │        [-0.025, 0.010] │       │
# │                                           │        [-0.025, 0.035] │       │
# │                                           │        [-0.025, 0.075] │       │
# │                                           │        [-0.025, 0.150] │       │
# │                                           │        [-0.025, 0.250] │       │
# │                                           │        [-0.015,-0.250] │       │
# │                                           │        [-0.015,-0.150] │       │
# │                                           │        [-0.015,-0.075] │       │
# │                                           │        [-0.015,-0.035] │       │
# │                                           │        [-0.015,-0.010] │       │
# │                                           │        [-0.015, 0.010] │       │
# │                                           │        [-0.015, 0.035] │       │
# │                                           │        [-0.015, 0.075] │       │
# │                                           │        [-0.015, 0.150] │       │
# │                                           │        [-0.015, 0.250] │       │
# │                                           │        [-0.005,-0.250] │       │
# │                                           │        [-0.005,-0.150] │       │
# │                                           │        [-0.005,-0.075] │       │
# │                                           │        [-0.005,-0.035] │       │
# │                                           │        [-0.005,-0.010] │       │
# │                                           │        [-0.005, 0.010] │       │
# │                                           │        [-0.005, 0.035] │       │
# │                                           │        [-0.005, 0.075] │       │
# │                                           │        [-0.005, 0.150] │       │
# │                                           │        [-0.005, 0.250] │       │
# │                                           │        [ 0.000,-0.250] │       │
# │                                           │        [ 0.000,-0.150] │       │
# │                                           │        [ 0.000,-0.075] │       │
# │                                           │        [ 0.000,-0.035] │       │
# │                                           │        [ 0.000,-0.010] │       │
# │                                           │        [ 0.000, 0.010] │       │
# │                                           │        [ 0.000, 0.035] │       │
# │                                           │        [ 0.000, 0.075] │       │
# │                                           │        [ 0.000, 0.150] │       │
# │                                           │        [ 0.000, 0.250] │       │
# │                                           │        [ 0.005,-0.250] │       │
# │                                           │        [ 0.005,-0.150] │       │
# │                                           │        [ 0.005,-0.075] │       │
# │                                           │        [ 0.005,-0.035] │       │
# │                                           │        [ 0.005,-0.010] │       │
# │                                           │        [ 0.005, 0.010] │       │
# │                                           │        [ 0.005, 0.035] │       │
# │                                           │        [ 0.005, 0.075] │       │
# │                                           │        [ 0.005, 0.150] │       │
# │                                           │        [ 0.005, 0.250] │       │
# │                                           │        [ 0.015,-0.250] │       │
# │                                           │        [ 0.015,-0.150] │       │
# │                                           │        [ 0.015,-0.075] │       │
# │                                           │        [ 0.015,-0.035] │       │
# │                                           │        [ 0.015,-0.010] │       │
# │                                           │        [ 0.015, 0.010] │       │
# │                                           │        [ 0.015, 0.035] │       │
# │                                           │        [ 0.015, 0.075] │       │
# │                                           │        [ 0.015, 0.150] │       │
# │                                           │        [ 0.015, 0.250] │       │
# │                                           │        [ 0.025,-0.250] │       │
# │                                           │        [ 0.025,-0.150] │       │
# │                                           │        [ 0.025,-0.075] │       │
# │                                           │        [ 0.025,-0.035] │       │
# │                                           │        [ 0.025,-0.010] │       │
# │                                           │        [ 0.025, 0.010] │       │
# │                                           │        [ 0.025, 0.035] │       │
# │                                           │        [ 0.025, 0.075] │       │
# │                                           │        [ 0.025, 0.150] │       │
# │                                           │        [ 0.025, 0.250] │       │
# │                                           │        [ 0.035,-0.250] │       │
# │                                           │        [ 0.035,-0.150] │       │
# │                                           │        [ 0.035,-0.075] │       │
# │                                           │        [ 0.035,-0.035] │       │
# │                                           │        [ 0.035,-0.010] │       │
# │                                           │        [ 0.035, 0.010] │       │
# │                                           │        [ 0.035, 0.035] │       │
# │                                           │        [ 0.035, 0.075] │       │
# │                                           │        [ 0.035, 0.150] │       │
# │                                           │        [ 0.035, 0.250] │       │
# │                                           │                        │       │
# │ [shear, veer]                             │         Total [(unit)] │       │
# │                                           │                        │       │
# │                                           │          [ -8.5,-60.5] │       │
# │                                           │          [ -8.5,-36.3] │       │
# │                                           │          [ -8.5,-18.1] │       │
# │                                           │          [ -8.5, -8.5] │       │
# │                                           │          [ -8.5, -2.4] │       │
# │                                           │          [ -8.5,  2.4] │       │
# │                                           │          [ -8.5,  8.5] │       │
# │                                           │          [ -8.5, 18.1] │       │
# │                                           │          [ -8.5, 36.3] │       │
# │                                           │          [ -8.5, 60.5] │       │
# │                                           │          [ -6.1,-60.5] │       │
# │                                           │          [ -6.1,-36.3] │       │
# │                                           │          [ -6.1,-18.1] │       │
# │                                           │          [ -6.1, -8.5] │       │
# │                                           │          [ -6.1, -2.4] │       │
# │                                           │          [ -6.1,  2.4] │       │
# │                                           │          [ -6.1,  8.5] │       │
# │                                           │          [ -6.1, 18.1] │       │
# │                                           │          [ -6.1, 36.3] │       │
# │                                           │          [ -6.1, 60.5] │       │
# │                                           │          [ -3.6,-60.5] │       │
# │                                           │          [ -3.6,-36.3] │       │
# │                                           │          [ -3.6,-18.1] │       │
# │                                           │          [ -3.6, -8.5] │       │
# │                                           │          [ -3.6, -2.4] │       │
# │                                           │          [ -3.6,  2.4] │       │
# │                                           │          [ -3.6,  8.5] │       │
# │                                           │          [ -3.6, 18.1] │       │
# │                                           │          [ -3.6, 36.3] │       │
# │                                           │          [ -3.6, 60.5] │       │
# │                                           │          [ -1.2,-60.5] │       │
# │                                           │          [ -1.2,-36.3] │       │
# │                                           │          [ -1.2,-18.1] │       │
# │                                           │          [ -1.2, -8.5] │       │
# │                                           │          [ -1.2, -2.4] │       │
# │                                           │          [ -1.2,  2.4] │       │
# │                                           │          [ -1.2,  8.5] │       │
# │                                           │          [ -1.2, 18.1] │       │
# │                                           │          [ -1.2, 36.3] │       │
# │                                           │          [ -1.2, 60.5] │       │
# │                                           │          [  0.0,-60.5] │       │
# │                                           │          [  0.0,-36.3] │       │
# │                                           │          [  0.0,-18.1] │       │
# │                                           │          [  0.0, -8.5] │       │
# │                                           │          [  0.0, -2.4] │       │
# │                                           │          [  0.0,  2.4] │       │
# │                                           │          [  0.0,  8.5] │       │
# │                                           │          [  0.0, 18.1] │       │
# │                                           │          [  0.0, 36.3] │       │
# │                                           │          [  0.0, 60.5] │       │
# │                                           │          [  1.2,-60.5] │       │
# │                                           │          [  1.2,-36.3] │       │
# │                                           │          [  1.2,-18.1] │       │
# │                                           │          [  1.2, -8.5] │       │
# │                                           │          [  1.2, -2.4] │       │
# │                                           │          [  1.2,  2.4] │       │
# │                                           │          [  1.2,  8.5] │       │
# │                                           │          [  1.2, 18.1] │       │
# │                                           │          [  1.2, 36.3] │       │
# │                                           │          [  1.2, 60.5] │       │
# │                                           │          [  3.6,-60.5] │       │
# │                                           │          [  3.6,-36.3] │       │
# │                                           │          [  3.6,-18.1] │       │
# │                                           │          [  3.6, -8.5] │       │
# │                                           │          [  3.6, -2.4] │       │
# │                                           │          [  3.6,  2.4] │       │
# │                                           │          [  3.6,  8.5] │       │
# │                                           │          [  3.6, 18.1] │       │
# │                                           │          [  3.6, 36.3] │       │
# │                                           │          [  3.6, 60.5] │       │
# │                                           │          [  6.1,-60.5] │       │
# │                                           │          [  6.1,-36.3] │       │
# │                                           │          [  6.1,-18.1] │       │
# │                                           │          [  6.1, -8.5] │       │
# │                                           │          [  6.1, -2.4] │       │
# │                                           │          [  6.1,  2.4] │       │
# │                                           │          [  6.1,  8.5] │       │
# │                                           │          [  6.1, 18.1] │       │
# │                                           │          [  6.1, 36.3] │       │
# │                                           │          [  6.1, 60.5] │       │
# │                                           │          [  8.5,-60.5] │       │
# │                                           │          [  8.5,-36.3] │       │
# │                                           │          [  8.5,-18.1] │       │
# │                                           │          [  8.5, -8.5] │       │
# │                                           │          [  8.5, -2.4] │       │
# │                                           │          [  8.5,  2.4] │       │
# │                                           │          [  8.5,  8.5] │       │
# │                                           │          [  8.5, 18.1] │       │
# │                                           │          [  8.5, 36.3] │       │
# │                                           │          [  8.5, 60.5] │       │
# │                                           │                        │       │
# ├───────────────────────────────────────────┼────────────────────────┼───────┤
# │ Table generated on 2025-07-07 at 12:01:13 │                        │       │
# └───────────────────────────────────────────┴────────────────────────┴───────┘
# sn035_vn250
# sn035_vn150
# sn035_vn075
# sn035_vn035
# sn035_vn010
# sn035_v010
# sn035_v035
# sn035_v075
# sn035_v150
# sn035_v250
# sn025_vn250
# sn025_vn150
# sn025_vn075
# sn025_vn035
# sn025_vn010
# sn025_v010
# sn025_v035
# sn025_v075
# sn025_v150
# sn025_v250
# sn015_vn250
# sn015_vn150
# sn015_vn075
# sn015_vn035
# sn015_vn010
# sn015_v010
# sn015_v035
# sn015_v075
# sn015_v150
# sn015_v250
# sn005_vn250
# sn005_vn150
# sn005_vn075
# sn005_vn035
# sn005_vn010
# sn005_v010
# sn005_v035
# sn005_v075
# sn005_v150
# sn005_v250
# s000_vn250
# s000_vn150
# s000_vn075
# s000_vn035
# s000_vn010
# s000_v010
# s000_v035
# s000_v075
# s000_v150
# s000_v250
# s005_vn250
# s005_vn150
# s005_vn075
# s005_vn035
# s005_vn010
# s005_v010
# s005_v035
# s005_v075
# s005_v150
# s005_v250
# s015_vn250
# s015_vn150
# s015_vn075
# s015_vn035
# s015_vn010
# s015_v010
# s015_v035
# s015_v075
# s015_v150
# s015_v250
# s025_vn250
# s025_vn150
# s025_vn075
# s025_vn035
# s025_vn010
# s025_v010
# s025_v035
# s025_v075
# s025_v150
# s025_v250
# s035_vn250
# s035_vn150
# s035_vn075
# s035_vn035
# s035_vn010
# s035_v010
# s035_v035
# s035_v075
# s035_v150
# s035_v250
# Done.

# %%
postproc.convergence(opt_params)

# %%
postproc.parproc(15, opt_params, 'fast')
# Out:
# Preparing to process these files:
#
#  1. s00_v00/wrfout_d02_0001-01-01_00_00_00
#  2. s00_v03/wrfout_d02_0001-01-01_00_00_00
#  3. s00_v06/wrfout_d02_0001-01-01_00_00_00
#  4. s00_v12/wrfout_d02_0001-01-01_00_00_00
#  5. s00_vn03/wrfout_d02_0001-01-01_00_00_00
#  6. s00_vn06/wrfout_d02_0001-01-01_00_00_00
#  7. s00_vn12/wrfout_d02_0001-01-01_00_00_00
#  8. s03_v00/wrfout_d02_0001-01-01_00_00_00
#  9. s03_v06/wrfout_d02_0001-01-01_00_00_00
# 10. s03_vn06/wrfout_d02_0001-01-01_00_00_00
# 11. s06_v00/wrfout_d02_0001-01-01_00_00_00
# 12. sn03_v00/wrfout_d02_0001-01-01_00_00_00
# 13. sn03_v06/wrfout_d02_0001-01-01_00_00_00
# 14. sn03_vn06/wrfout_d02_0001-01-01_00_00_00
# 15. sn06_v00/wrfout_d02_0001-01-01_00_00_00
# Processing WRF outputs with 15 parallel processes...
# Working on s00_v06...
# Working on s00_v03...
# Working on s00_v12...
# Working on s00_vn03...
# Working on s00_vn06...
# Working on s00_vn12...
# Working on s03_v06...
# Working on s03_v00...
# Working on s03_vn06...
# Working on s00_v00...
#
# Working on sn03_v00...
# Working on sn03_v06...
# Working on sn03_vn06...
# Working on s06_v00...
# Working on sn06_v00...
# Finished in 0 min and 0 sec.
