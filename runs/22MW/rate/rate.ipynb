# %% [markdown]
# ## Configure sweep on 10 MW turbine with specified shear/veer rates

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from wrf_io import *
from itertools import product
import pickle

# %%
opt_params={}

opt_params['allocation']     = 'ATM170028' 
opt_params['partition']      = 'spr' 
opt_params['runtime']        = '12:00:00'
opt_params['system']         = 'stampede'
opt_params['num_nodes']      = 3

opt_params['exclude_time']   = 10
opt_params['save_interval']  = 10

# opt_params['base_dir']       = '/scratch/09909/smata/test'
opt_params['base_dir']       = '/scratch/09909/smata/wrf_les_sweep/runs/22MW/rate'
opt_params['wrf_path']       = '/work2/09909/smata/stampede3/WRF_LES'
opt_params['template_path']  = '/scratch/09909/smata/wrf_les_sweep/templates'
opt_params['turb_model']     = 'iea22MW'
opt_params['rotor_model']    = 'GAD'
opt_params['slice_loc']      = 1
   
opt_params['print_table']    = True
   
opt_params['plot_outer']     = True
opt_params['save_outer']     = False
opt_params['outer_align']    = False
   
opt_params['plot_inner']     = True
opt_params['save_inner']     = False
   
opt_params['save_both']      = False
opt_params['outer_pad']      = 75

opt_params['plot_profiles']  = True
opt_params['save_profiles']  = True

opt_params['batch_submit']   = True

opt_params['prof_type']      = 'Idealized'
opt_params['shear_type']     = 'Rate'
# opt_params['shear']          = [-6,-4,-2,0,2,4,6]
# opt_params['veer']           = [-80,-40,-20,-10,0,10,20,40,80]
# opt_params['veer']           = [-80,-70,-60,-50,-40,-30,-20,-10,0,10,20,30,40,50,60,70,80]

opt_params['shear']          = [-0.03,-0.02,-0.01,0,0.01,0.02,0.03]
opt_params['veer']           = [-0.2,-0.1,-0.05,-0.025,0,0.025,0.05,0.1,0.2]

# opt_params['shear']          = [0]
# opt_params['veer']           = [0]

opt_params['excluded_pairs'] = []
# opt_params['excluded_pairs'] = [pair for pair in product([-6,-4,-2,0,2,4,6], [-80,-70,-60,-50,-40,-30,-20,-10,0,10,20,30,40,50,60,70,80])]

opt_params['Ufst']           = 7

# with open('/scratch/09909/smata/wrf_les_sweep/runs/22MW/rate/gad_sweep/parameters.pkl', 'wb') as f:
#     pickle.dump(opt_params, f)

# %%
flag = sweep.setup(opt_params, 'GAD')
# Out:
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━┓
# ┃ Parameter                                 ┃                  Value ┃ Issue ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━┩
# │ TIME CONTROL AND SETUP                    │                        │       │
# │                                           │                        │       │
# │ Run time                                  │            00:00:15:00 │       │
# │                                           │                        │       │
# │ Outer dt                                  │               0.40 sec │       │
# │ Inner dt                                  │               0.04 sec │       │
# │                                           │                        │       │
# │ Processes                                 │                    104 │       │
# ├───────────────────────────────────────────┼────────────────────────┼───────┤
# │ TURBINE                                   │                        │       │
# │                                           │                        │       │
# │ Model                                     │                iea22MW │       │
# │ Diameter                                  │               284.00 m │       │
# │ Hub diameter                              │                 8.40 m │       │
# │ Inner domain x location                   │               1.41 x D │       │
# │ Turbine x location                        │               3.94 x D │       │
# │ z location                                │                378.0 m │       │
# ├───────────────────────────────────────────┼────────────────────────┼───────┤
# │ ROTOR                                     │                        │       │
# │                                           │                        │       │
# │ Model                                     │                    GAD │       │
# │ Rotation                                  │              clockwise │       │
# │ Sections                                  │                    224 │       │
# │ Elements                                  │                     37 │       │
# │                                           │                        │       │
# │ nSeries                                   │                   8288 │       │
# │                                           │                        │       │
# │ V0 location                               │                0.5 x D │   >3D │
# │                                           │                        │       │
# │ Shapiro                                   │                     ON │       │
# ├───────────────────────────────────────────┼────────────────────────┼───────┤
# │ DOMAIN                                    │                        │       │
# │                                           │                        │       │
# │ Outer mesh size                           │              7,087,487 │       │
# │ Inner mesh Size                           │             20,319,607 │       │
# │ Mesh ratio                                │                   2.87 │       │
# │                                           │                        │       │
# │ Outer dx, dy                              │         [40.0, 40.0] m │       │
# │ Inner dx, dy                              │         [ 4.0,  4.0] m │       │
# │ dz                                        │                 4.04 m │       │
# │                                           │                        │       │
# │ Outer [Lx, Ly, Lz]                        │ [35.4, 21.3,  2.7] x D │       │
# │ Inner [Lx, Ly, Lz]                        │ [ 4.2,  5.1,  2.7] x D │       │
# │                                           │                        │       │
# │ Outer [Nx, Ny, Nz]                        │     [ 251,  151,  187] │       │
# │ Inner [Nx, Ny, Nz]                        │     [ 301,  361,  187] │       │
# │                                           │                        │       │
# │ Lateral blockage                          │                  4.70% │       │
# ├───────────────────────────────────────────┼────────────────────────┼───────┤
# │ DECOMPOSITION                             │                        │       │
# │                                           │                        │       │
# │ Outer cell width in x                     │                     31 │       │
# │ Outer cell width in y                     │                     11 │       │
# │                                           │                        │       │
# │ Inner cell width in x                     │                     37 │       │
# │ Inner cell width in y                     │                     27 │       │
# │                                           │                        │       │
# │ MOD(301 - 1, 10)                          │                      0 │       │
# │ MOD(361 - 1, 10)                          │                      0 │       │
# │                                           │                        │       │
# │ Rotor contained in pool?                  │                    Yes │       │
# ├───────────────────────────────────────────┼────────────────────────┼───────┤
# │ INFLOW                                    │                        │       │
# │                                           │                        │       │
# │ Profile type                              │       Linear Idealized │       │
# │                                           │                        │       │
# │ Total cases                               │                     63 │       │
# │                                           │                        │       │
# │ [shear, veer]                             │        Rate [(unit)/m] │       │
# │                                           │                        │       │
# │                                           │        [-0.030,-0.200] │       │
# │                                           │        [-0.030,-0.100] │       │
# │                                           │        [-0.030,-0.050] │       │
# │                                           │        [-0.030,-0.025] │       │
# │                                           │        [-0.030, 0.000] │       │
# │                                           │        [-0.030, 0.025] │       │
# │                                           │        [-0.030, 0.050] │       │
# │                                           │        [-0.030, 0.100] │       │
# │                                           │        [-0.030, 0.200] │       │
# │                                           │        [-0.020,-0.200] │       │
# │                                           │        [-0.020,-0.100] │       │
# │                                           │        [-0.020,-0.050] │       │
# │                                           │        [-0.020,-0.025] │       │
# │                                           │        [-0.020, 0.000] │       │
# │                                           │        [-0.020, 0.025] │       │
# │                                           │        [-0.020, 0.050] │       │
# │                                           │        [-0.020, 0.100] │       │
# │                                           │        [-0.020, 0.200] │       │
# │                                           │        [-0.010,-0.200] │       │
# │                                           │        [-0.010,-0.100] │       │
# │                                           │        [-0.010,-0.050] │       │
# │                                           │        [-0.010,-0.025] │       │
# │                                           │        [-0.010, 0.000] │       │
# │                                           │        [-0.010, 0.025] │       │
# │                                           │        [-0.010, 0.050] │       │
# │                                           │        [-0.010, 0.100] │       │
# │                                           │        [-0.010, 0.200] │       │
# │                                           │        [ 0.000,-0.200] │       │
# │                                           │        [ 0.000,-0.100] │       │
# │                                           │        [ 0.000,-0.050] │       │
# │                                           │        [ 0.000,-0.025] │       │
# │                                           │        [ 0.000, 0.000] │       │
# │                                           │        [ 0.000, 0.025] │       │
# │                                           │        [ 0.000, 0.050] │       │
# │                                           │        [ 0.000, 0.100] │       │
# │                                           │        [ 0.000, 0.200] │       │
# │                                           │        [ 0.010,-0.200] │       │
# │                                           │        [ 0.010,-0.100] │       │
# │                                           │        [ 0.010,-0.050] │       │
# │                                           │        [ 0.010,-0.025] │       │
# │                                           │        [ 0.010, 0.000] │       │
# │                                           │        [ 0.010, 0.025] │       │
# │                                           │        [ 0.010, 0.050] │       │
# │                                           │        [ 0.010, 0.100] │       │
# │                                           │        [ 0.010, 0.200] │       │
# │                                           │        [ 0.020,-0.200] │       │
# │                                           │        [ 0.020,-0.100] │       │
# │                                           │        [ 0.020,-0.050] │       │
# │                                           │        [ 0.020,-0.025] │       │
# │                                           │        [ 0.020, 0.000] │       │
# │                                           │        [ 0.020, 0.025] │       │
# │                                           │        [ 0.020, 0.050] │       │
# │                                           │        [ 0.020, 0.100] │       │
# │                                           │        [ 0.020, 0.200] │       │
# │                                           │        [ 0.030,-0.200] │       │
# │                                           │        [ 0.030,-0.100] │       │
# │                                           │        [ 0.030,-0.050] │       │
# │                                           │        [ 0.030,-0.025] │       │
# │                                           │        [ 0.030, 0.000] │       │
# │                                           │        [ 0.030, 0.025] │       │
# │                                           │        [ 0.030, 0.050] │       │
# │                                           │        [ 0.030, 0.100] │       │
# │                                           │        [ 0.030, 0.200] │       │
# │                                           │                        │       │
# │ [shear, veer]                             │         Total [(unit)] │       │
# │                                           │                        │       │
# │                                           │          [ -8.5,-56.8] │       │
# │                                           │          [ -8.5,-28.4] │       │
# │                                           │          [ -8.5,-14.2] │       │
# │                                           │          [ -8.5, -7.1] │       │
# │                                           │          [ -8.5,  0.0] │       │
# │                                           │          [ -8.5,  7.1] │       │
# │                                           │          [ -8.5, 14.2] │       │
# │                                           │          [ -8.5, 28.4] │       │
# │                                           │          [ -8.5, 56.8] │       │
# │                                           │          [ -5.7,-56.8] │       │
# │                                           │          [ -5.7,-28.4] │       │
# │                                           │          [ -5.7,-14.2] │       │
# │                                           │          [ -5.7, -7.1] │       │
# │                                           │          [ -5.7,  0.0] │       │
# │                                           │          [ -5.7,  7.1] │       │
# │                                           │          [ -5.7, 14.2] │       │
# │                                           │          [ -5.7, 28.4] │       │
# │                                           │          [ -5.7, 56.8] │       │
# │                                           │          [ -2.8,-56.8] │       │
# │                                           │          [ -2.8,-28.4] │       │
# │                                           │          [ -2.8,-14.2] │       │
# │                                           │          [ -2.8, -7.1] │       │
# │                                           │          [ -2.8,  0.0] │       │
# │                                           │          [ -2.8,  7.1] │       │
# │                                           │          [ -2.8, 14.2] │       │
# │                                           │          [ -2.8, 28.4] │       │
# │                                           │          [ -2.8, 56.8] │       │
# │                                           │          [  0.0,-56.8] │       │
# │                                           │          [  0.0,-28.4] │       │
# │                                           │          [  0.0,-14.2] │       │
# │                                           │          [  0.0, -7.1] │       │
# │                                           │          [  0.0,  0.0] │       │
# │                                           │          [  0.0,  7.1] │       │
# │                                           │          [  0.0, 14.2] │       │
# │                                           │          [  0.0, 28.4] │       │
# │                                           │          [  0.0, 56.8] │       │
# │                                           │          [  2.8,-56.8] │       │
# │                                           │          [  2.8,-28.4] │       │
# │                                           │          [  2.8,-14.2] │       │
# │                                           │          [  2.8, -7.1] │       │
# │                                           │          [  2.8,  0.0] │       │
# │                                           │          [  2.8,  7.1] │       │
# │                                           │          [  2.8, 14.2] │       │
# │                                           │          [  2.8, 28.4] │       │
# │                                           │          [  2.8, 56.8] │       │
# │                                           │          [  5.7,-56.8] │       │
# │                                           │          [  5.7,-28.4] │       │
# │                                           │          [  5.7,-14.2] │       │
# │                                           │          [  5.7, -7.1] │       │
# │                                           │          [  5.7,  0.0] │       │
# │                                           │          [  5.7,  7.1] │       │
# │                                           │          [  5.7, 14.2] │       │
# │                                           │          [  5.7, 28.4] │       │
# │                                           │          [  5.7, 56.8] │       │
# │                                           │          [  8.5,-56.8] │       │
# │                                           │          [  8.5,-28.4] │       │
# │                                           │          [  8.5,-14.2] │       │
# │                                           │          [  8.5, -7.1] │       │
# │                                           │          [  8.5,  0.0] │       │
# │                                           │          [  8.5,  7.1] │       │
# │                                           │          [  8.5, 14.2] │       │
# │                                           │          [  8.5, 28.4] │       │
# │                                           │          [  8.5, 56.8] │       │
# │                                           │                        │       │
# ├───────────────────────────────────────────┼────────────────────────┼───────┤
# │ Table generated on 2025-06-27 at 08:50:05 │                        │       │
# └───────────────────────────────────────────┴────────────────────────┴───────┘
# sn030_vn200
# sn030_vn100
# sn030_vn050
# sn030_vn025
# sn030_v000
# sn030_v025
# sn030_v050
# sn030_v100
# sn030_v200
# sn020_vn200
# sn020_vn100
# sn020_vn050
# sn020_vn025
# sn020_v000
# sn020_v025
# sn020_v050
# sn020_v100
# sn020_v200
# sn010_vn200
# sn010_vn100
# sn010_vn050
# sn010_vn025
# sn010_v000
# sn010_v025
# sn010_v050
# sn010_v100
# sn010_v200
# s000_vn200
# s000_vn100
# s000_vn050
# s000_vn025
# s000_v000
# s000_v025
# s000_v050
# s000_v100
# s000_v200
# s010_vn200
# s010_vn100
# s010_vn050
# s010_vn025
# s010_v000
# s010_v025
# s010_v050
# s010_v100
# s010_v200
# s020_vn200
# s020_vn100
# s020_vn050
# s020_vn025
# s020_v000
# s020_v025
# s020_v050
# s020_v100
# s020_v200
# s030_vn200
# s030_vn100
# s030_vn050
# s030_vn025
# s030_v000
# s030_v025
# s030_v050
# s030_v100
# s030_v200
# Done.

# %%
postproc.convergence(opt_params)

# %%
postproc.parproc(15, opt_params, 'fast')
# Out:
# Preparing to process these files:
#
#  1. s00_v00/wrfout_d02_0001-01-01_00_00_00
#  2. s00_v03/wrfout_d02_0001-01-01_00_00_00
#  3. s00_v06/wrfout_d02_0001-01-01_00_00_00
#  4. s00_v12/wrfout_d02_0001-01-01_00_00_00
#  5. s00_vn03/wrfout_d02_0001-01-01_00_00_00
#  6. s00_vn06/wrfout_d02_0001-01-01_00_00_00
#  7. s00_vn12/wrfout_d02_0001-01-01_00_00_00
#  8. s03_v00/wrfout_d02_0001-01-01_00_00_00
#  9. s03_v06/wrfout_d02_0001-01-01_00_00_00
# 10. s03_vn06/wrfout_d02_0001-01-01_00_00_00
# 11. s06_v00/wrfout_d02_0001-01-01_00_00_00
# 12. sn03_v00/wrfout_d02_0001-01-01_00_00_00
# 13. sn03_v06/wrfout_d02_0001-01-01_00_00_00
# 14. sn03_vn06/wrfout_d02_0001-01-01_00_00_00
# 15. sn06_v00/wrfout_d02_0001-01-01_00_00_00
# Processing WRF outputs with 15 parallel processes...
# Working on s00_v06...
# Working on s00_v03...
# Working on s00_v12...
# Working on s00_vn03...
# Working on s00_vn06...
# Working on s00_vn12...
# Working on s03_v06...
# Working on s03_v00...
# Working on s03_vn06...
# Working on s00_v00...
#
# Working on sn03_v00...
# Working on sn03_v06...
# Working on sn03_vn06...
# Working on s06_v00...
# Working on sn06_v00...
# Finished in 0 min and 0 sec.
